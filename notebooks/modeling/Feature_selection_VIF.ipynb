# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import ppscore as pps
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('../../data/by_student_group/grocery_added.csv',low_memory=False)

df.drop(columns=['Unnamed: 0','National School Lunch Program [Public School] 2020-21','School Type [Public School] 2020-21',
                'County Name_y','District Name_y', 'School Name_y','CDS',"No. of Service Days Req'd"],inplace=True)
df.rename(columns ={'County Name_x':'County_Name','District Name_x':'District_Name',
                    'Lowest Grade Offered [Public School] 2020-21':'Lowest Grade Offered',
                    'School Name_x':'School_Name',
'Total Students, All Grades (Excludes AE) [Public School] 2020-21':'Total_Students(No-AE)',
'Total Students, All Grades (Includes AE) [Public School] 2020-21':'Total_Students(With-AE)',
'Grades 1-8 Students [Public School] 2020-21':'1-8th_Students',
    'Pupil/Teacher Ratio [Public School] 2020-21':'Pupil/Teacher-Ratio',
       'Grades 9-12 Students [Public School] 2020-21':'9-12_Students',
        'Full-Time Equivalent (FTE) Teachers [Public School] 2020-21':'FTE_Teachers',
                    'Hispanic - male [Public School] 2020-21':'Hispanic_Male',
       'Hispanic - female [Public School] 2020-21':'Hispanic_Female',
       'Black or African American - male [Public School] 2020-21':'Black_or_AA_M',
       'Black or African American - female [Public School] 2020-21':'Black_or_AA_F'}
          ,inplace=True)
df.shape
# Out:
# (316683, 95)

# %%
## get only 11th grade scores 
dfe= df[df['Grade']==11].copy()
dfe.shape
# Out:
# (56794, 95)

# %% [markdown]
# ## convert data types and map small categotical values togeather to prep for one hot encoding

# %%
dfe['Charter_School'] = np.where(dfe['Charter_School']=='N',0,1)
dfe['Charter_School'].value_counts()
# Out:
# 0    42771
# 1    14023
# Name: Charter_School, dtype: int64

# %%
dfe['Education_type'] = pd.Series(dfe['Education_type'], dtype="string")

# %%
dfe['Education_type'] = dfe['Education_type'].replace({
                                                   'Community Day School':'other',
                                                   'Opportunity School':'other',
                                                 'Youth Authority School':'other',
                                                  'Special Education School':'other'})

# %%
dfe['Education_type'].value_counts()
# Out:
# Traditional                     44569
# Continuation School              4385
# Alternative School of Choice     2867
# County Community School           626
# other                             302
# Juvenile Court School             300
# Name: Education_type, dtype: int64

# %%
dfe['Demographic Name'].value_counts()
# Out:
# Hispanic or Latino                                                  5588
# White                                                               3346
# All Students                                                        2716
# Not armed forces family member                                      2715
# Not migrant education                                               2712
# Not homeless                                                        2688
# IFEP and EO (Initial fluent English proficient and English only)    2657
# No reported disabilities                                            2640
# Economically disadvantaged                                          2383
# Male                                                                2375
# EO (English only)                                                   2317
# Female                                                              2250
# Ever�EL                                                             2049
# Not economically disadvantaged                                      1904
# RFEP (Reclassified fluent English proficient)                       1856
# Asian                                                               1626
# Some college (includes AA degree)                                   1595
# High school graduate                                                1534
# College graduate                                                    1341
# Not a high school graduate                                          1250
# Reported disabilities                                               1203
# Declined to state                                                   1089
# EL (English learner)                                                1036
# ELs enrolled 12 months or more                                      1026
# Graduate school/Post graduate                                        994
# Two or more races                                                    990
# Black or African American                                            935
# IFEP (Initial fluent English proficient)                             713
# Filipino                                                             698
# Homeless                                                             273
# Armed forces family member                                           162
# Migrant education                                                     73
# Native Hawaiian or Pacific Islander                                   31
# American Indian or Alaska Native                                      23
# ELs enrolled less than 12 months                                       6
# Name: Demographic Name, dtype: int64

# %%
dfe['Demographic Name'] = dfe['Demographic Name'].replace({'Native Hawaiian or Pacific Islander':'Asian'})

## need to drop small groups Migrant education

dfe.drop(dfe[dfe['Demographic Name']=='Migrant education'].index,axis=0,inplace=True)
dfe.drop(dfe[dfe['Demographic Name']=='ELs enrolled less than 12 months'].index,axis=0,inplace=True)
dfe.drop(dfe[dfe['Demographic Name']=='American Indian or Alaska Native'].index,axis=0,inplace=True)

# %%
 dfe['Low Grade'] =  dfe['Low Grade'].replace(
 {'8':'11 or 8','5':'5,4,3,2,1','4':'5,4,3,2,1','3':'5,4,3,2,1',
  '1':'5,4,3,2,1','2':'5,4,3,2,1','11':'11 or 8'})
dfe['Low Grade'] =pd.Series( dfe['Low Grade'], dtype="string")

# %%
 dfe['Low Grade'].value_counts()
# Out:
# 9            42838
# K             6634
# 6             2297
# 7             1968
# P             1574
# 10             524
# 11 or 8        361
# 5,4,3,2,1      326
# Name: Low Grade, dtype: Int64

# %%
dfe['Zip_Code'] = pd.Series(dfe['Zip_Code'], dtype="string")
dfe['Zip_Code'].sample(5)
print(dfe.Zip_Code.dtypes)
# Out:
# string

# %%
def calculate_vif(df, features):   
    from sklearn.linear_model import LinearRegression
    vif, tolerance = {}, {}
    # all the features that you want to examine
    for feature in features:
        # extract all the other features you will regress against
        X = [f for f in features if f != feature]        
        X, y = df[X], df[feature]
        # extract r-squared from the fit
        r2 = LinearRegression().fit(X, y).score(X, y)                
        
        # calculate tolerance
        tolerance[feature] = 1 - r2
        # calculate VIF
        vif[feature] = 1/(tolerance[feature])
    # return VIF DataFrame
    return pd.DataFrame({'VIF': vif, 'Tolerance': tolerance})

# %%
df['Test ID'].value_counts()
# Out:
# Mathematics                       160303
# English Language Arts/Literacy    156380
# Name: Test ID, dtype: int64

# %%
model_df = dfe[[
    # categorical features
    'County_Name', 'District_Name', 'School_Name', 'Zip_Code',
   'Demographic Name', 'Student Group','District Type','Test ID',
       'School Type', 'Education_type', 'Charter_School',  'Low Grade',
    # target y
    'Mean Scale Score',
    # continuous features 
    'Total Tested at Reporting Level',
       'Total Tested with Scores at Reporting Level',
               'Students Enrolled', 'Students Tested', 
    
    ## aggregates of scores would give data leakage can not use 
    
#        'Percentage Standard Exceeded', 'Percentage Standard Met',
#        'Percentage Standard Met and Above', 'Percentage Standard Nearly Met',
#        'Percentage Standard Not Met',
    
    
    'Students with Scores', 
       'Enrollment', 'Free_Meal_count', 'Percent_Eligible',
       'FRPM_Count', 'Percent_Eligible_FRPM',
       'Free_Meal_Count', 'Percent_Eligible_Free', 
         'Latitude', 'Longitude',
       '9-12_Students',
       'FTE_Teachers', 'Pupil/Teacher-Ratio', 'Hispanic_Male',
       'Hispanic_Female', 'Black_or_AA_M', 'Black_or_AA_F',
       'Asian or Asian/Pacific Islander - male [Public School] 2020-21',
       'Asian or Asian/Pacific Islander - female [Public School] 2020-21',
                'Avg_21',
        'Total Salary Schedule FTE', 'Lowest Salary Offered',
       'Average Salary Paid', 'Highest Entry Level Step',
       'Highest Salary Offered', 'Salary at BA+60 Step 10', '2020–21 P‑2 ADA',
       '% Salary Change Over 2019–20', 'EDP 365', 'Current\nExpense ADA',
       'Current\nExpense Per ADA', 'Estimated Total Population',
       'Estimated Population 5-17', 'est_num_u17_pov', 'Grocery_3mile',
       'Grocery_dist'
               ]].copy()

# %%
model_df['District Type'] =model_df['District Type'].replace({
    'State Board of Education':'other','Non-School Locations':'other'})

model_df['Education_type'] = model_df['Education_type'].replace({
   'Community Day School':'other','Opportunity School':'other',
    'Youth Authority School':'other','Special Education School':'other'
})

# %%
model_df['Education_type'].value_counts()
# Out:
# Traditional                     44486
# Continuation School              4385
# Alternative School of Choice     2867
# County Community School           626
# other                             302
# Juvenile Court School             300
# Name: Education_type, dtype: int64

# %%
model_df['District Type'].value_counts()
# Out:
# Unified School District             38866
# High School District                13006
# County Office of Education (COE)     2545
# Elementary School District           1822
# other                                 283
# Name: District Type, dtype: int64

# %%
numeric = ['Mean Scale Score',
    'Total Tested at Reporting Level',
           'Zip_Code',
       'Total Tested with Scores at Reporting Level',
               'Students Enrolled', 'Students Tested', 
        'Students with Scores', 
       'Enrollment', 'Free_Meal_count', 'Percent_Eligible',
       'FRPM_Count', 'Percent_Eligible_FRPM',
       'Free_Meal_Count', 'Percent_Eligible_Free', 
         'Latitude', 'Longitude',
       '9-12_Students',
       'FTE_Teachers', 'Pupil/Teacher-Ratio', 'Hispanic_Male',
       'Hispanic_Female', 'Black_or_AA_M', 'Black_or_AA_F',
       'Asian or Asian/Pacific Islander - male [Public School] 2020-21',
       'Asian or Asian/Pacific Islander - female [Public School] 2020-21',
                'Avg_21',
        'Total Salary Schedule FTE', 'Lowest Salary Offered',
       'Average Salary Paid', 'Highest Entry Level Step',
       'Highest Salary Offered', 'Salary at BA+60 Step 10', '2020–21 P‑2 ADA',
       '% Salary Change Over 2019–20', 'EDP 365', 'Current\nExpense ADA',
       'Current\nExpense Per ADA', 'Estimated Total Population',
       'Estimated Population 5-17', 'est_num_u17_pov', 'Grocery_3mile',
       'Grocery_dist']

# %%
model_df[numeric]= model_df[numeric].apply(pd.to_numeric,errors='coerce')

# %% [markdown]
# ## Check for nulls to clean

# %%
m = pd.DataFrame([model_df.isnull().sum(),100*model_df.isnull().mean()])
m = m.T
m.columns=['count', '%']
m = m.sort_values(by='count',ascending=False)
m.head(25)
# Out:
#                                                       count          %
# Black_or_AA_F                                       16317.0  28.781839
# Asian or Asian/Pacific Islander - female [Publi...  15874.0  28.000423
# Black_or_AA_M                                       15817.0  27.899880
# Asian or Asian/Pacific Islander - male [Public ...  15581.0  27.483596
# Pupil/Teacher-Ratio                                 13304.0  23.467156
# Hispanic_Female                                     13260.0  23.389543
# Hispanic_Male                                       13260.0  23.389543
# 9-12_Students                                       13260.0  23.389543
# FTE_Teachers                                        13179.0  23.246666
# Longitude                                           12999.0  22.929161
# Latitude                                            12999.0  22.929161
# Grocery_dist                                         7098.0  12.520285
# Grocery_3mile                                        6432.0  11.345516
# Avg_21                                               4110.0   7.249700
# School Type                                          3726.0   6.572356
# Education_type                                       3726.0   6.572356
# Zip_Code                                             3556.0   6.272490
# School_Name                                          3556.0   6.272490
# Free_Meal_Count                                       170.0   0.299866
# District Type                                         170.0   0.299866
# Low Grade                                             170.0   0.299866
# Percent_Eligible_Free                                 170.0   0.299866
# Percent_Eligible_FRPM                                 170.0   0.299866
# FRPM_Count                                            170.0   0.299866
# Percent_Eligible                                      170.0   0.299866

# %% [markdown]
# ## Impute nulls with district then county averages for numeric columns nulls

# %%
cols = model_df[numeric].columns.values
for i in cols:
    model_df[i] = model_df[i].fillna(model_df.groupby(['District_Name'])[i].transform('mean'))
for i in cols:
    model_df[i] = model_df[i].fillna(model_df.groupby(['County_Name'])[i].transform('mean'))

# %%
m = pd.DataFrame([model_df.isnull().sum(),100*model_df.isnull().mean()])
m = m.T
m.columns=['count', '%']
m = m.sort_values(by='count',ascending=False)
m.head(20)
# Out:
#                                                      count         %
# School Type                                         3726.0  6.572356
# Education_type                                      3726.0  6.572356
# School_Name                                         3556.0  6.272490
# Black_or_AA_M                                        273.0  0.481549
# Black_or_AA_F                                        266.0  0.469202
# District Type                                        170.0  0.299866
# Low Grade                                            170.0  0.299866
# Asian or Asian/Pacific Islander - male [Public ...    99.0  0.174628
# Longitude                                             81.0  0.142877
# Hispanic_Male                                         81.0  0.142877
# Pupil/Teacher-Ratio                                   81.0  0.142877
# FTE_Teachers                                          81.0  0.142877
# 9-12_Students                                         81.0  0.142877
# Latitude                                              81.0  0.142877
# Asian or Asian/Pacific Islander - female [Publi...    81.0  0.142877
# Hispanic_Female                                       81.0  0.142877
# 2020–21 P‑2 ADA                                       46.0  0.081140
# Highest Salary Offered                                46.0  0.081140
# Highest Entry Level Step                              46.0  0.081140
# Average Salary Paid                                   46.0  0.081140

# %%
## the all name blanks were probably the county averages 

## drop nulls 

print(model_df.shape)
model_df = model_df.dropna(how='any',axis=0)
model_df.shape
# Out:
# (56692, 53)
# (52665, 53)

# %%
model_df.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
m = pd.DataFrame([model_df.isnull().sum(),100*model_df.isnull().mean()])
m = m.T
m.columns=['count', '%']
m = m.sort_values(by='count',ascending=False)
m.head(5)
# Out:
#                      count    %
# County_Name            0.0  0.0
# 9-12_Students          0.0  0.0
# Pupil/Teacher-Ratio    0.0  0.0
# Hispanic_Male          0.0  0.0
# Hispanic_Female        0.0  0.0

# %%
model_df.columns
# Out:
# Index(['County_Name', 'District_Name', 'School_Name', 'Zip_Code',
#        'Demographic Name', 'Student Group', 'District Type', 'Test ID',
#        'School Type', 'Education_type', 'Charter_School', 'Low Grade',
#        'Mean Scale Score', 'Total Tested at Reporting Level',
#        'Total Tested with Scores at Reporting Level', 'Students Enrolled',
#        'Students Tested', 'Students with Scores', 'Enrollment',
#        'Free_Meal_count', 'Percent_Eligible', 'FRPM_Count',
#        'Percent_Eligible_FRPM', 'Free_Meal_Count', 'Percent_Eligible_Free',
#        'Latitude', 'Longitude', '9-12_Students', 'FTE_Teachers',
#        'Pupil/Teacher-Ratio', 'Hispanic_Male', 'Hispanic_Female',
#        'Black_or_AA_M', 'Black_or_AA_F',
#        'Asian or Asian/Pacific Islander - male [Public School] 2020-21',
#        'Asian or Asian/Pacific Islander - female [Public School] 2020-21',
#        'Avg_21', 'Total Salary Schedule FTE', 'Lowest Salary Offered',
#        'Average Salary Paid', 'Highest Entry Level Step',
#        'Highest Salary Offered', 'Salary at BA+60 Step 10', '2020–21 P‑2 ADA',
#        '% Salary Change Over 2019–20', 'EDP 365', 'Current\nExpense ADA',
#        'Current\nExpense Per ADA', 'Estimated Total Population',
#        'Estimated Population 5-17', 'est_num_u17_pov', 'Grocery_3mile',
#        'Grocery_dist'],
#       dtype='object')

# %% [markdown]
# ## Use numerical columns to calculate Variance Inflaciton Factor (VIF)

# %%
vifs = ['Total Tested with Scores at Reporting Level',
'Free_Meal_count',
     'Zip_Code',
     'Latitude', 
               'Longitude',
       '9-12_Students', 
               'FTE_Teachers', 
               'Pupil/Teacher-Ratio', 
       'Hispanic_Female',
               'Black_or_AA_F',
       'Asian or Asian/Pacific Islander - female [Public School] 2020-21',
       'Avg_21',
       'Average Salary Paid', 
       'Highest Salary Offered', 
       '% Salary Change Over 2019–20',
               'EDP 365',
       'Current\nExpense Per ADA', 
               'Estimated Total Population',
 'est_num_u17_pov', 'Grocery_3mile',
       'Grocery_dist']

# %%
vif_df= calculate_vif(model_df[vifs],model_df[vifs].columns.values)
vif_df
# Out:
#                                                             VIF  Tolerance
# Total Tested with Scores at Reporting Level            1.156885   0.864390
# Free_Meal_count                                        2.355629   0.424515
# Zip_Code                                               8.280288   0.120769
# Latitude                                              17.008010   0.058796
# Longitude                                             11.700972   0.085463
# 9-12_Students                                         23.001598   0.043475
# FTE_Teachers                                          19.404711   0.051534
# Pupil/Teacher-Ratio                                    1.672761   0.597814
# Hispanic_Female                                        5.776784   0.173107
# Black_or_AA_F                                          1.460812   0.684551
# Asian or Asian/Pacific Islander - female [Publi...     2.446158   0.408804
# Avg_21                                                 2.158532   0.463278
# Average Salary Paid                                    7.763313   0.128811
# Highest Salary Offered                                 8.403164   0.119003
# % Salary Change Over 2019–20                           1.387512   0.720715
# EDP 365                                             1977.798041   0.000506
# Current\nExpense Per ADA                               1.088904   0.918355
# Estimated Total Population                           388.529329   0.002574
# est_num_u17_pov                                     1463.714794   0.000683
# Grocery_3mile                                          1.679525   0.595407
# Grocery_dist                                           1.040151   0.961399

# %% [markdown]
# ## Remove columns to reduce multicolinerality

# %%
vifs = ['Total Tested with Scores at Reporting Level',
'Free_Meal_count',
     'Latitude', 
#                'Longitude',
        'Zip_Code',
#        '9-12_Students', 
               'FTE_Teachers', 
               'Pupil/Teacher-Ratio', 
       'Hispanic_Female',
#                'Hispanic_Male',
               'Black_or_AA_F',
       'Asian or Asian/Pacific Islander - female [Public School] 2020-21',
       'Avg_21',
       'Average Salary Paid', 
#        'Highest Salary Offered', 
#        '% Salary Change Over 2019–20',
#                'EDP 365',
       'Current\nExpense Per ADA', 
#                'Estimated Total Population',
 'est_num_u17_pov', 'Grocery_3mile',
       'Grocery_dist']
vif_df= calculate_vif(model_df[vifs],model_df[vifs].columns.values)
vif_df
# Out:
#                                                          VIF  Tolerance
# Total Tested with Scores at Reporting Level         1.151882   0.868144
# Free_Meal_count                                     2.311326   0.432652
# Latitude                                            5.791114   0.172678
# Zip_Code                                            7.201064   0.138868
# FTE_Teachers                                        5.189864   0.192683
# Pupil/Teacher-Ratio                                 1.357217   0.736802
# Hispanic_Female                                     5.157765   0.193882
# Black_or_AA_F                                       1.409304   0.709570
# Asian or Asian/Pacific Islander - female [Publi...  2.087451   0.479053
# Avg_21                                              1.744179   0.573336
# Average Salary Paid                                 1.788439   0.559147
# Current\nExpense Per ADA                            1.079144   0.926660
# est_num_u17_pov                                     2.148902   0.465354
# Grocery_3mile                                       1.570320   0.636813
# Grocery_dist                                        1.030520   0.970384

# %% [markdown]
# ## 'EDP 365', and est_num_u17_pov seem to be highly correlated and had to use Current\nExpense Per ADA, instead

# %%
fig, ax = plt.subplots(figsize=(12,12))
fig = sns.heatmap(model_df[vifs].corr(),annot=True)
plt.title('selected feature linear correlation heat map')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,12))
fig = sns.heatmap(model_df[vifs].corr(method='spearman'),annot=True)
plt.title('selected feature Spearmn correlation heat map')
plt.show()

# %%
pps.score(model_df,'Avg_21','Mean Scale Score')
# Out:
# {'x': 'Avg_21',
#  'y': 'Mean Scale Score',
#  'ppscore': 0.18683600858506344,
#  'case': 'regression',
#  'is_valid_score': True,
#  'metric': 'mean absolute error',
#  'baseline_score': 61.1901,
#  'model_score': 49.75758595107911,
#  'model': DecisionTreeRegressor()}

# %%
pps.score(model_df,'Latitude','Mean Scale Score')
# Out:
# {'x': 'Latitude',
#  'y': 'Mean Scale Score',
#  'ppscore': 0.2937313321197931,
#  'case': 'regression',
#  'is_valid_score': True,
#  'metric': 'mean absolute error',
#  'baseline_score': 61.1901,
#  'model_score': 43.21665041445665,
#  'model': DecisionTreeRegressor()}

# %%
pps.score(model_df,'Longitude','Mean Scale Score')
# Out:
# {'x': 'Longitude',
#  'y': 'Mean Scale Score',
#  'ppscore': 0.2877445176873602,
#  'case': 'regression',
#  'is_valid_score': True,
#  'metric': 'mean absolute error',
#  'baseline_score': 61.1901,
#  'model_score': 43.58298418825866,
#  'model': DecisionTreeRegressor()}

# %%
vifs
# Out:
# ['Total Tested with Scores at Reporting Level',
#  'Percentage Standard Exceeded',
#  'Percentage Standard Not Met',
#  'Free_Meal_count',
#  'Latitude',
#  'FTE_Teachers',
#  'Pupil/Teacher-Ratio',
#  'Hispanic_Female',
#  'Black_or_AA_F',
#  'Asian or Asian/Pacific Islander - female [Public School] 2020-21',
#  'Avg_21',
#  'Average Salary Paid',
#  'Current\nExpense Per ADA',
#  'est_num_u17_pov',
#  'Grocery_3mile',
#  'Grocery_dist']

# %%
pps = model_df[['Mean Scale Score','Total Tested with Scores at Reporting Level',
 'Free_Meal_count',
 'Latitude',
 'FTE_Teachers',
 'Pupil/Teacher-Ratio',
 'Hispanic_Female',
 'Black_or_AA_F',
 'Asian or Asian/Pacific Islander - female [Public School] 2020-21',
 'Avg_21',
 'Average Salary Paid',
 'Current\nExpense Per ADA',
 'est_num_u17_pov',
 'Grocery_3mile',
 'Grocery_dist']].copy()

# %%
df = pd.DataFrame(pps)

# %%
## use the model and look up the example below to finish
##the pps score for the features

# %%
fig, ax = plt.subplots(figsize=(12,12))
matrix_df = pps.matrix(df)[['x', 'y', 'ppscore']].pivot(columns='x', index='y', values='ppscore')
fig = sns.heatmap(matrix_df, vmin=0, vmax=1, cmap="Blues", linewidths=0.5, annot=True)
plt.title('Predictive Power Score')
plt.show()

# %%
## Distance to nearest grocery store got a ppscore of .24

# %%
pps.predictors(model_df, "Mean Scale Score")
# Out:
#                                                     x                 y  \
# 0                               Percent_Eligible_Free  Mean Scale Score
# 1                               Percent_Eligible_FRPM  Mean Scale Score
# 2                                    Percent_Eligible  Mean Scale Score
# 3                                         School_Name  Mean Scale Score
# 4                                            Latitude  Mean Scale Score
# 5                                          Enrollment  Mean Scale Score
# 6                                           Longitude  Mean Scale Score
# 7                                        FTE_Teachers  Mean Scale Score
# 8                                       9-12_Students  Mean Scale Score
# 9                                        Grocery_dist  Mean Scale Score
# 10                                Pupil/Teacher-Ratio  Mean Scale Score
# 11  Asian or Asian/Pacific Islander - female [Publ...  Mean Scale Score
# 12                                           Zip_Code  Mean Scale Score
# 13                                             Avg_21  Mean Scale Score
# 14  Asian or Asian/Pacific Islander - male [Public...  Mean Scale Score
# 15                                         FRPM_Count  Mean Scale Score
# 16                                    Free_Meal_count  Mean Scale Score
# 17                                      District_Name  Mean Scale Score
# 18                                   Demographic Name  Mean Scale Score
# 19                                    Free_Meal_Count  Mean Scale Score
# 20                                    Hispanic_Female  Mean Scale Score
# 21                                        School Type  Mean Scale Score
# 22                                      Hispanic_Male  Mean Scale Score
# 23                                     Education_type  Mean Scale Score
# 24                             Highest Salary Offered  Mean Scale Score
# 25                            Salary at BA+60 Step 10  Mean Scale Score
# 26                                    2020–21 P‑2 ADA  Mean Scale Score
# 27                                            EDP 365  Mean Scale Score
# 28                                Average Salary Paid  Mean Scale Score
# 29                          Estimated Population 5-17  Mean Scale Score
# 30                         Estimated Total Population  Mean Scale Score
# 31                               Current\nExpense ADA  Mean Scale Score
# 32                              Lowest Salary Offered  Mean Scale Score
# 33                           Current\nExpense Per ADA  Mean Scale Score
# 34                          Total Salary Schedule FTE  Mean Scale Score
# 35                                    est_num_u17_pov  Mean Scale Score
# 36                                      Black_or_AA_M  Mean Scale Score
# 37                                      Black_or_AA_F  Mean Scale Score
# 38                       % Salary Change Over 2019–20  Mean Scale Score
# 39                                            Test ID  Mean Scale Score
# 40                           Highest Entry Level Step  Mean Scale Score
# 41                                        County_Name  Mean Scale Score
# 42                                      Student Group  Mean Scale Score
# 43                                      Grocery_3mile  Mean Scale Score
# 44                                      District Type  Mean Scale Score
# 45                                          Low Grade  Mean Scale Score
# 46                                     Charter_School  Mean Scale Score
# 47                    Total Tested at Reporting Level  Mean Scale Score
# 48        Total Tested with Scores at Reporting Level  Mean Scale Score
# 49                                  Students Enrolled  Mean Scale Score
# 50                                    Students Tested  Mean Scale Score
# 51                               Students with Scores  Mean Scale Score
#
#      ppscore        case  is_valid_score               metric  baseline_score  \
# 0   0.345851  regression            True  mean absolute error         61.1901
# 1   0.339751  regression            True  mean absolute error         61.1901
# 2   0.339518  regression            True  mean absolute error         61.1901
# 3   0.332634  regression            True  mean absolute error         61.1901
# 4   0.293731  regression            True  mean absolute error         61.1901
# 5   0.288604  regression            True  mean absolute error         61.1901
# 6   0.287745  regression            True  mean absolute error         61.1901
# 7   0.267616  regression            True  mean absolute error         61.1901
# 8   0.244752  regression            True  mean absolute error         61.1901
# 9   0.243707  regression            True  mean absolute error         61.1901
# 10  0.237133  regression            True  mean absolute error         61.1901
# 11  0.198990  regression            True  mean absolute error         61.1901
# 12  0.190163  regression            True  mean absolute error         61.1901
# 13  0.186836  regression            True  mean absolute error         61.1901
# 14  0.179244  regression            True  mean absolute error         61.1901
# 15  0.176996  regression            True  mean absolute error         61.1901
# 16  0.174194  regression            True  mean absolute error         61.1901
# 17  0.173814  regression            True  mean absolute error         61.1901
# 18  0.162608  regression            True  mean absolute error         61.1901
# 19  0.153667  regression            True  mean absolute error         61.1901
# 20  0.148768  regression            True  mean absolute error         61.1901
# 21  0.141136  regression            True  mean absolute error         61.1901
# 22  0.136402  regression            True  mean absolute error         61.1901
# 23  0.124641  regression            True  mean absolute error         61.1901
# 24  0.111019  regression            True  mean absolute error         61.1901
# 25  0.109521  regression            True  mean absolute error         61.1901
# 26  0.109507  regression            True  mean absolute error         61.1901
# 27  0.109481  regression            True  mean absolute error         61.1901
# 28  0.109086  regression            True  mean absolute error         61.1901
# 29  0.108983  regression            True  mean absolute error         61.1901
# 30  0.108982  regression            True  mean absolute error         61.1901
# 31  0.108722  regression            True  mean absolute error         61.1901
# 32  0.108432  regression            True  mean absolute error         61.1901
# 33  0.108292  regression            True  mean absolute error         61.1901
# 34  0.107258  regression            True  mean absolute error         61.1901
# 35  0.106442  regression            True  mean absolute error         61.1901
# 36  0.075470  regression            True  mean absolute error         61.1901
# 37  0.074997  regression            True  mean absolute error         61.1901
# 38  0.042379  regression            True  mean absolute error         61.1901
# 39  0.041491  regression            True  mean absolute error         61.1901
# 40  0.033538  regression            True  mean absolute error         61.1901
# 41  0.032320  regression            True  mean absolute error         61.1901
# 42  0.024796  regression            True  mean absolute error         61.1901
# 43  0.018488  regression            True  mean absolute error         61.1901
# 44  0.014787  regression            True  mean absolute error         61.1901
# 45  0.013533  regression            True  mean absolute error         61.1901
# 46  0.000000  regression            True  mean absolute error         61.1901
# 47  0.000000  regression            True  mean absolute error         61.1901
# 48  0.000000  regression            True  mean absolute error         61.1901
# 49  0.000000  regression            True  mean absolute error         61.1901
# 50  0.000000  regression            True  mean absolute error         61.1901
# 51  0.000000  regression            True  mean absolute error         61.1901
#
#     model_score                    model
# 0     40.027468  DecisionTreeRegressor()
# 1     40.400675  DecisionTreeRegressor()
# 2     40.414933  DecisionTreeRegressor()
# 3     40.836192  DecisionTreeRegressor()
# 4     43.216650  DecisionTreeRegressor()
# 5     43.530377  DecisionTreeRegressor()
# 6     43.582984  DecisionTreeRegressor()
# 7     44.814681  DecisionTreeRegressor()
# 8     46.213716  DecisionTreeRegressor()
# 9     46.277653  DecisionTreeRegressor()
# 10    46.679894  DecisionTreeRegressor()
# 11    49.013895  DecisionTreeRegressor()
# 12    49.553993  DecisionTreeRegressor()
# 13    49.757586  DecisionTreeRegressor()
# 14    50.222138  DecisionTreeRegressor()
# 15    50.359724  DecisionTreeRegressor()
# 16    50.531176  DecisionTreeRegressor()
# 17    50.554428  DecisionTreeRegressor()
# 18    51.240124  DecisionTreeRegressor()
# 19    51.787206  DecisionTreeRegressor()
# 20    52.086949  DecisionTreeRegressor()
# 21    52.553949  DecisionTreeRegressor()
# 22    52.843631  DecisionTreeRegressor()
# 23    53.563309  DecisionTreeRegressor()
# 24    54.396861  DecisionTreeRegressor()
# 25    54.488489  DecisionTreeRegressor()
# 26    54.489329  DecisionTreeRegressor()
# 27    54.490942  DecisionTreeRegressor()
# 28    54.515129  DecisionTreeRegressor()
# 29    54.521436  DecisionTreeRegressor()
# 30    54.521451  DecisionTreeRegressor()
# 31    54.537400  DecisionTreeRegressor()
# 32    54.555163  DecisionTreeRegressor()
# 33    54.563726  DecisionTreeRegressor()
# 34    54.626972  DecisionTreeRegressor()
# 35    54.676887  DecisionTreeRegressor()
# 36    56.572078  DecisionTreeRegressor()
# 37    56.601036  DecisionTreeRegressor()
# 38    58.596912  DecisionTreeRegressor()
# 39    58.651291  DecisionTreeRegressor()
# 40    59.137911  DecisionTreeRegressor()
# 41    59.212427  DecisionTreeRegressor()
# 42    59.672859  DecisionTreeRegressor()
# 43    60.058812  DecisionTreeRegressor()
# 44    60.285267  DecisionTreeRegressor()
# 45    60.362022  DecisionTreeRegressor()
# 46    61.226080  DecisionTreeRegressor()
# 47    63.138469  DecisionTreeRegressor()
# 48    62.981512  DecisionTreeRegressor()
# 49    63.170296  DecisionTreeRegressor()
# 50    62.528300  DecisionTreeRegressor()
# 51    62.392265  DecisionTreeRegressor()

# %%
model_df.columns
# Out:
# Index(['County_Name', 'District_Name', 'School_Name', 'Zip_Code',
#        'Demographic Name', 'Student Group', 'District Type', 'Test ID',
#        'School Type', 'Education_type', 'Charter_School', 'Low Grade',
#        'Mean Scale Score', 'Total Tested at Reporting Level',
#        'Total Tested with Scores at Reporting Level', 'Students Enrolled',
#        'Students Tested', 'Students with Scores', 'Enrollment',
#        'Free_Meal_count', 'Percent_Eligible', 'FRPM_Count',
#        'Percent_Eligible_FRPM', 'Free_Meal_Count', 'Percent_Eligible_Free',
#        'Latitude', 'Longitude', '9-12_Students', 'FTE_Teachers',
#        'Pupil/Teacher-Ratio', 'Hispanic_Male', 'Hispanic_Female',
#        'Black_or_AA_M', 'Black_or_AA_F',
#        'Asian or Asian/Pacific Islander - male [Public School] 2020-21',
#        'Asian or Asian/Pacific Islander - female [Public School] 2020-21',
#        'Avg_21', 'Total Salary Schedule FTE', 'Lowest Salary Offered',
#        'Average Salary Paid', 'Highest Entry Level Step',
#        'Highest Salary Offered', 'Salary at BA+60 Step 10', '2020–21 P‑2 ADA',
#        '% Salary Change Over 2019–20', 'EDP 365', 'Current\nExpense ADA',
#        'Current\nExpense Per ADA', 'Estimated Total Population',
#        'Estimated Population 5-17', 'est_num_u17_pov', 'Grocery_3mile',
#        'Grocery_dist'],
#       dtype='object')

# %%
final = model_df[[
    'Mean Scale Score','County_Name', 'District_Name', 'School_Name', 
       'Demographic Name', 'Student Group', 'District Type', 'Test ID',
       'School Type', 'Education_type', 'Charter_School', 'Low Grade',
        'Total Tested at Reporting Level',
       'Total Tested with Scores at Reporting Level', 'Students Enrolled',
       'Students Tested', 'Students with Scores', 'Enrollment',
       'Free_Meal_count', 'Percent_Eligible', 'FRPM_Count',
       'Percent_Eligible_FRPM', 'Free_Meal_Count', 'Percent_Eligible_Free',
       'Latitude', 'Longitude', '9-12_Students', 'FTE_Teachers',
       'Pupil/Teacher-Ratio', 'Hispanic_Male', 'Hispanic_Female',
       'Black_or_AA_M', 'Black_or_AA_F',
       'Asian or Asian/Pacific Islander - male [Public School] 2020-21',
       'Asian or Asian/Pacific Islander - female [Public School] 2020-21',
       'Avg_21', 'Total Salary Schedule FTE', 'Lowest Salary Offered',
       'Average Salary Paid', 'Highest Entry Level Step',
       'Highest Salary Offered', 'Salary at BA+60 Step 10', '2020–21 P‑2 ADA',
       '% Salary Change Over 2019–20', 'EDP 365', 'Current\nExpense ADA',
       'Current\nExpense Per ADA', 'Estimated Total Population',
       'Estimated Population 5-17', 'est_num_u17_pov', 'Grocery_3mile',
       'Grocery_dist']]

# %%
final = model_df[[
    'Mean Scale Score',
    'Total Tested with Scores at Reporting Level',
    'Demographic Name', 'Student Group', 'District Type', 'Test ID',
       'School Type', 'Education_type', 'Charter_School', 'Low Grade',
    'Free_Meal_count',
     'Latitude', 
   'FTE_Teachers', 
   'Pupil/Teacher-Ratio', 
       'Hispanic_Female',
        'Black_or_AA_F',
       'Asian or Asian/Pacific Islander - female [Public School] 2020-21',
       'Avg_21',
       'Average Salary Paid', 
       'Current\nExpense Per ADA', 
     'est_num_u17_pov', 
    'Grocery_3mile',
       'Grocery_dist']].copy()

# %%
final.to_csv('../../data/model/final_df.csv')

# %%
final.shape
# Out:
# (52665, 23)
