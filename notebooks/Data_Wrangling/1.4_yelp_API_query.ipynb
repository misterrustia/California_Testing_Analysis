# %%
import pandas as pd
import numpy as np
from yelpapi import YelpAPI
from config import api_key, client_id

# %% [markdown]
# With school zip codes can query yelp api,

# %%
yelp_api = YelpAPI(api_key)


client_id = client_id
api_key = api_key

# %% [markdown]
# # what is distance units from yelp api?
#
# ## look up liquor stores/ grovery stores /
#
# ## look at east palo alto versus palo alto and see if ratio looks different or not, need to find distance
# ## that I can relate from the school / how far and what kind of stores should I relate to each school?
# # do any of the ratios created correlate with the mean score?
# ## look at nulls per county to see if there are target areas that need to be cleaned up or re eval as sf is
# missing hella scores
# ##

# %%
yelp_data=[]
# maybe make this an empty data frame then concat each one to the next
# shape of results being variable could make this messy ? 
# says as each copy ois made better to lake list then concat list once 
for ZIP in zipcodes: ## list from data set with zipcodes 
    zip_info={} # dict 
    for buiness in community: # list of areas 
        term = buiness
        location = ZIP
        search_limit = 50
        response = yelp_api.search_query(term = term,
                                 location = location,
                                 limit = search_limit)
        cols = list(response['businesses'][0].keys())
        data = pd.DataFrame(columns=cols)
        for biz in response['businesses']:
            data = data.append(biz, ignore_index=True)
        data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-96ab0c87e072> in <module>
# ----> 1 for ZIP in zipcodes: ## list from data set with zipcodes
#       2     zip_info={}
#       3     for buiness in community:
#       4         end# list of areas
#       5
#
# NameError: name 'zipcodes' is not defined

# %%
term = 'grocery store'
location = '96087'
search_limit = 50
response = yelp_api.search_query(term = term,
                                 location = location,
                                 limit = search_limit)
cols = list(response['businesses'][0].keys())
data = pd.DataFrame(columns=cols)
for biz in response['businesses']:
    data = data.append(biz, ignore_index=True)
data.head()
# Out:
#                        id                              alias  \
# 0  Au225Drt0-ENomQWANYcog  mountain-market-place-weaverville
# 1  ALflIN5VVW8qThUvp0bERA    lakeshore-villa-market-lakehead
# 2  a-vugKAGBOdGAw0v_YEjQA       tops-super-foods-weaverville
# 3  LmwxevWbmqMPm4PD3eqPVg         holiday-market-weaverville
# 4  pBf7hz2kVGuniOgrShOdBA                   js-market-shasta
#
#                      name                                          image_url  \
# 0   Mountain Market Place  https://s3-media4.fl.yelpcdn.com/bphoto/iVsDTD...
# 1  Lakeshore Villa Market  https://s3-media2.fl.yelpcdn.com/bphoto/dL77SA...
# 2        Tops Super Foods  https://s3-media4.fl.yelpcdn.com/bphoto/yo-W99...
# 3          Holiday Market  https://s3-media2.fl.yelpcdn.com/bphoto/jLZjlD...
# 4              J's Market  https://s3-media1.fl.yelpcdn.com/bphoto/C9TGZ6...
#
#   is_closed                                                url review_count  \
# 0     False  https://www.yelp.com/biz/mountain-market-place...            9
# 1     False  https://www.yelp.com/biz/lakeshore-villa-marke...            4
# 2     False  https://www.yelp.com/biz/tops-super-foods-weav...           30
# 3     False  https://www.yelp.com/biz/holiday-market-weaver...            7
# 4     False  https://www.yelp.com/biz/js-market-shasta?adju...            4
#
#                                           categories  rating  \
# 0  [{'alias': 'grocery', 'title': 'Grocery'}, {'a...     4.5
# 1         [{'alias': 'grocery', 'title': 'Grocery'}]     4.5
# 2         [{'alias': 'grocery', 'title': 'Grocery'}]     3.0
# 3         [{'alias': 'grocery', 'title': 'Grocery'}]     3.5
# 4         [{'alias': 'grocery', 'title': 'Grocery'}]     5.0
#
#                                          coordinates transactions price  \
# 0  {'latitude': 40.7335714218449, 'longitude': -1...           []    $$
# 1     {'latitude': 40.88778, 'longitude': -122.3851}           []    $$
# 2    {'latitude': 40.72085, 'longitude': -122.92732}           []   $$$
# 3   {'latitude': 40.72103, 'longitude': -122.927216}           []   NaN
# 4  {'latitude': 40.5967445373535, 'longitude': -1...           []    $$
#
#                                             location         phone  \
# 0  {'address1': '508 Main St', 'address2': None, ...  +15306232656
# 1  {'address1': '20750 Lakeshore Dr', 'address2':...  +15302388615
# 2  {'address1': '1665 Main St', 'address2': '', '...  +15306232494
# 3  {'address1': '1665 S Main St', 'address2': Non...  +15306232494
# 4  {'address1': '15438 Highway 299 W', 'address2'...  +15302433080
#
#     display_phone      distance
# 0  (530) 623-2656  29514.825596
# 1  (530) 238-8615  34128.249553
# 2  (530) 623-2494  27913.036988
# 3  (530) 623-2494  27935.143674
# 4  (530) 243-3080  11620.018818

# %%
term = 'liquor'
location = '96087'
search_limit = 50
response = yelp_api.search_query(term = term,
                                 location = location,
                                 limit = search_limit)
cols = list(response['businesses'][0].keys())
data = pd.DataFrame(columns=cols)
for biz in response['businesses']:
    data = data.append(biz, ignore_index=True)
data.head()
# Out:
#                        id                            alias  \
# 0  Ly30G_29CAUBfFcWK6ehCg              liquor-barn-redding
# 1  ALflIN5VVW8qThUvp0bERA  lakeshore-villa-market-lakehead
# 2  AIx0c_sSBI642Xdfz76jcQ          lakewood-market-redding
# 3  7KiwL7Tx5N9xED7Dsv74kQ          duffys-liquors-anderson
# 4  W2jVpz7gb9RQx9jmJM7s5w              liquor-king-redding
#
#                      name                                          image_url  \
# 0             Liquor Barn  https://s3-media4.fl.yelpcdn.com/bphoto/pjVhfk...
# 1  Lakeshore Villa Market  https://s3-media2.fl.yelpcdn.com/bphoto/dL77SA...
# 2         Lakewood Market  https://s3-media2.fl.yelpcdn.com/bphoto/uWh4WA...
# 3         Duffy's Liquors  https://s3-media2.fl.yelpcdn.com/bphoto/mZGTSV...
# 4             Liquor King  https://s3-media2.fl.yelpcdn.com/bphoto/rp3iMF...
#
#   is_closed                                                url review_count  \
# 0     False  https://www.yelp.com/biz/liquor-barn-redding?a...           42
# 1     False  https://www.yelp.com/biz/lakeshore-villa-marke...            4
# 2     False  https://www.yelp.com/biz/lakewood-market-reddi...            3
# 3     False  https://www.yelp.com/biz/duffys-liquors-anders...           10
# 4     False  https://www.yelp.com/biz/liquor-king-redding?a...            2
#
#                                           categories  rating  \
# 0  [{'alias': 'beer_and_wine', 'title': 'Beer, Wi...     4.0
# 1         [{'alias': 'grocery', 'title': 'Grocery'}]     4.5
# 2  [{'alias': 'beer_and_wine', 'title': 'Beer, Wi...     5.0
# 3  [{'alias': 'beer_and_wine', 'title': 'Beer, Wi...     3.5
# 4  [{'alias': 'beer_and_wine', 'title': 'Beer, Wi...     3.5
#
#                                          coordinates transactions price  \
# 0  {'latitude': 40.5692232043026, 'longitude': -1...           []    $$
# 1     {'latitude': 40.88778, 'longitude': -122.3851}           []    $$
# 2     {'latitude': 40.6195, 'longitude': -122.39745}           []     $
# 3  {'latitude': 40.452844, 'longitude': -122.299132}           []   $$$
# 4  {'latitude': 40.5616149902344, 'longitude': -1...           []   NaN
#
#                                             location         phone  \
# 0  {'address1': '2627 Bechelli Ln', 'address2': '...  +15302230452
# 1  {'address1': '20750 Lakeshore Dr', 'address2':...  +15302388615
# 2  {'address1': '901 Lake Blvd', 'address2': 'Ste...  +15302414997
# 3  {'address1': '2182 North St', 'address2': None...  +15303657050
# 4  {'address1': '3136 Bechelli Ln', 'address2': '...  +15302211069
#
#     display_phone      distance
# 0  (530) 223-0452  22701.205429
# 1  (530) 238-8615  34128.249553
# 2  (530) 241-4997  18507.755856
# 3  (530) 365-7050  33594.167953
# 4  (530) 221-1069  22873.685662

# %%
term = 'grocery store'
location = '94116'
search_limit = 50
response = yelp_api.search_query(term = term,
                                 location = location,
                                 limit = search_limit)
cols = list(response['businesses'][0].keys())
data = pd.DataFrame(columns=cols)
for biz in response['businesses']:
    data = data.append(biz, ignore_index=True)
data.head()
# Out:
#                        id                                  alias  \
# 0  bbDXbRE6O8BUbK3nyXdGCg  guss-community-market-san-francisco-6
# 1  KBsTJh5FVV_JQEVYvTDCWg               safeway-san-francisco-11
# 2  t2BIu94PpNJqzxKw18c4VQ                  lucky-san-francisco-3
# 3  9-Irfu8q-Mm3aEDXY18GbA       sunset-supermarket-san-francisco
# 4  C9YDe3DdURTN01ZaTefWWw               safeway-san-francisco-21
#
#                      name                                          image_url  \
# 0  Gus's Community Market  https://s3-media3.fl.yelpcdn.com/bphoto/AzXDW1...
# 1                 Safeway  https://s3-media2.fl.yelpcdn.com/bphoto/P3fTlr...
# 2                   Lucky  https://s3-media1.fl.yelpcdn.com/bphoto/zaSSYz...
# 3      Sunset Supermarket  https://s3-media4.fl.yelpcdn.com/bphoto/_qJ44z...
# 4                 Safeway  https://s3-media4.fl.yelpcdn.com/bphoto/srKv5b...
#
#   is_closed                                                url review_count  \
# 0     False  https://www.yelp.com/biz/guss-community-market...          311
# 1     False  https://www.yelp.com/biz/safeway-san-francisco...          259
# 2     False  https://www.yelp.com/biz/lucky-san-francisco-3...          224
# 3     False  https://www.yelp.com/biz/sunset-supermarket-sa...          141
# 4     False  https://www.yelp.com/biz/safeway-san-francisco...          260
#
#                                           categories  rating  \
# 0  [{'alias': 'markets', 'title': 'Fruits & Veggi...     4.5
# 1         [{'alias': 'grocery', 'title': 'Grocery'}]     2.5
# 2  [{'alias': 'grocery', 'title': 'Grocery'}, {'a...     3.0
# 3  [{'alias': 'intlgrocery', 'title': 'Internatio...     3.0
# 4         [{'alias': 'grocery', 'title': 'Grocery'}]     2.0
#
#                                          coordinates        transactions  \
# 0    {'latitude': 37.75281, 'longitude': -122.50357}  [pickup, delivery]
# 1  {'latitude': 37.754172, 'longitude': -122.4888...                  []
# 2    {'latitude': 37.73304, 'longitude': -122.48955}  [pickup, delivery]
# 3  {'latitude': 37.7381096, 'longitude': -122.497...                  []
# 4  {'latitude': 37.743262, 'longitude': -122.4739...                  []
#
#   price                                           location         phone  \
# 0    $$  {'address1': '3701 Noriega St', 'address2': 'U...  +14155640370
# 1    $$  {'address1': '2350 Noriega St', 'address2': ''...  +14156654565
# 2    $$  {'address1': '1515 Sloat Blvd', 'address2': ''...  +14156814300
# 3     $  {'address1': '2801 Vicente St', 'address2': ''...  +14155048188
# 4    $$  {'address1': '730 Taraval St', 'address2': '',...  +14156654136
#
#     display_phone     distance
# 0  (415) 564-0370  1728.843896
# 1  (415) 665-4565   688.666558
# 2  (415) 681-4300  1815.466998
# 3  (415) 504-8188  1658.603388
# 4  (415) 665-4136  1107.331782

# %%
cols = list(response['businesses'][0].keys())
data = pd.DataFrame(columns=cols)
for biz in response['businesses']:
    data = data.append(biz, ignore_index=True)
data.head()
# Out:
#                        id                           alias              name  \
# 0  BI40rGhpngLNPacrjWpseQ  dumpling-kitchen-san-francisco  Dumpling Kitchen
# 1  5iZp3XBPOUTIqQY7vGAfVA           hotline-san-francisco           Hotline
# 2  DSHzsZwazLD6g4Ot17A3iQ    dim-sum-club-san-francisco-3      Dim Sum Club
# 3  XhbkZ-5nUJ3bRy7uKPx7iQ       mr-szechuan-san-francisco       Mr Szechuan
# 4  QL_k7HiTGqvtjrT1SFImqg       noodle-stop-san-francisco       Noodle Stop
#
#                                            image_url is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/rggI1H...     False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/Iy0XS0...     False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/sWhZZ4...     False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/lFs0UW...     False
# 4  https://s3-media4.fl.yelpcdn.com/bphoto/1UsWyH...     False
#
#                                                  url review_count  \
# 0  https://www.yelp.com/biz/dumpling-kitchen-san-...         1821
# 1  https://www.yelp.com/biz/hotline-san-francisco...            7
# 2  https://www.yelp.com/biz/dim-sum-club-san-fran...          133
# 3  https://www.yelp.com/biz/mr-szechuan-san-franc...          396
# 4  https://www.yelp.com/biz/noodle-stop-san-franc...           18
#
#                                           categories  rating  \
# 0         [{'alias': 'chinese', 'title': 'Chinese'}]     4.0
# 1  [{'alias': 'korean', 'title': 'Korean'}, {'ali...     5.0
# 2  [{'alias': 'dimsum', 'title': 'Dim Sum'}, {'al...     4.0
# 3  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     4.5
# 4         [{'alias': 'noodles', 'title': 'Noodles'}]     4.0
#
#                                          coordinates  \
# 0     {'latitude': 37.7423, 'longitude': -122.48701}
# 1    {'latitude': 37.74203, 'longitude': -122.50446}
# 2  {'latitude': 37.74224411177974, 'longitude': -...
# 3    {'latitude': 37.74331, 'longitude': -122.47544}
# 4      {'latitude': 37.75395, 'longitude': -122.478}
#
#                                  transactions price  \
# 0                          [pickup, delivery]    $$
# 1                                          []   NaN
# 2  [restaurant_reservation, delivery, pickup]    $$
# 3                          [pickup, delivery]    $$
# 4                                          []   NaN
#
#                                             location         phone  \
# 0  {'address1': '1935 Taraval St', 'address2': ''...  +14156828938
# 1  {'address1': '3560 Taraval St', 'address2': No...  +14157026301
# 2  {'address1': '2237 Taraval St', 'address2': ''...  +14155928938
# 3  {'address1': '890 Taraval St', 'address2': Non...  +14157538788
# 4  {'address1': '1325 Noriega St', 'address2': ''...  +14157536688
#
#     display_phone     distance
# 0  (415) 682-8938   773.197264
# 1  (415) 702-6301  1920.394200
# 2  (415) 592-8938   908.906206
# 3  (415) 753-8788  1013.585493
# 4  (415) 753-6688   798.324388

# %%
term = 'Mexican restaurant bar'
location = 'Astoria, NY'
search_limit = 50
response = yelp_api.search_query(term = term,
                                 location = location,
                                 limit = search_limit)
type(response)
# Out:
# dict

# %%
cols = list(response['businesses'][0].keys())
data = pd.DataFrame(columns=cols)
for biz in response['businesses']:
    data = data.append(biz, ignore_index=True)
data.head()
# Out:
#                        id                                alias  \
# 0  EHUNrnIgnhwTnpOm3gEESg                       tacuba-astoria
# 1  yvva7IYpD6J7OfKlCdQrkw        mi-espiguita-taqueria-astoria
# 2  YFL1rAdlv7J0cswHVhvCtQ  ruta-oaxaca-mexican-cuisine-astoria
# 3  kd3yCktupzkZXjI6xDSkqA                 orale-mexico-astoria
# 4  ci0-GO_iMb0NdTCUYWjocQ         noche-de-margaritas-new-york
#
#                           name  \
# 0                       Tacuba
# 1        Mi Espiguita Taqueria
# 2  Ruta Oaxaca Mexican Cuisine
# 3                 ORALE MEXICO
# 4          Noche De Margaritas
#
#                                            image_url is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/xrzWf3...     False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/TEho39...     False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/_5Z0dN...     False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/W51EtQ...     False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/102pyt...     False
#
#                                                  url review_count  \
# 0  https://www.yelp.com/biz/tacuba-astoria?adjust...          710
# 1  https://www.yelp.com/biz/mi-espiguita-taqueria...          134
# 2  https://www.yelp.com/biz/ruta-oaxaca-mexican-c...          179
# 3  https://www.yelp.com/biz/orale-mexico-astoria?...           18
# 4  https://www.yelp.com/biz/noche-de-margaritas-n...          383
#
#                                           categories  rating  \
# 0  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     4.0
# 1         [{'alias': 'mexican', 'title': 'Mexican'}]     4.5
# 2         [{'alias': 'mexican', 'title': 'Mexican'}]     4.5
# 3         [{'alias': 'mexican', 'title': 'Mexican'}]     5.0
# 4         [{'alias': 'mexican', 'title': 'Mexican'}]     4.0
#
#                                          coordinates        transactions  \
# 0    {'latitude': 40.75609, 'longitude': -73.924441}  [pickup, delivery]
# 1  {'latitude': 40.7612033639422, 'longitude': -7...  [pickup, delivery]
# 2   {'latitude': 40.760579, 'longitude': -73.921857}  [pickup, delivery]
# 3  {'latitude': 40.7702872, 'longitude': -73.9183...  [pickup, delivery]
# 4  {'latitude': 40.7801018, 'longitude': -73.9497...  [pickup, delivery]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '35-01 36th St', 'address2': '', ...  +17187862727
# 1     $  {'address1': '32-44 31st St', 'address2': '', ...  +17187775648
# 2   $$$  {'address1': '35-03 Broadway', 'address2': Non...  +19293491228
# 3   NaN  {'address1': '3019 Astoria Blvd', 'address2': ...  +19178327813
# 4    $$  {'address1': '1726 2nd Ave', 'address2': '', '...  +12122895195
#
#     display_phone     distance
# 0  (718) 786-2727  1215.568416
# 1  (718) 777-5648   714.301080
# 2  (929) 349-1228   705.175234
# 3  (917) 832-7813   494.597826
# 4  (212) 289-5195  2759.294057

# %%
## look at table to join yelp too 

df = pd.read_csv('../data/processed/pov_added.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  County Code  District Code  \
# 0           0            10             121            1          61127
# 1           1            11             122            1          61127
# 2           2            12             123            1          61127
# 3           3            13             124            1          61127
# 4           4            14             129            1          61143
#
#    School Code  Test Year_x  Student Group ID  \
# 0       130450         2021                 1
# 1       130450         2021                 1
# 2       130450         2021                 1
# 3       130450         2021                 1
# 4       131177         2021                 1
#
#    Total Tested at Reporting Level  \
# 0                            217.0
# 1                            217.0
# 2                            219.0
# 3                            219.0
# 4                             74.0
#
#    Total Tested with Scores at Reporting Level  ...  \
# 0                                        216.0  ...
# 1                                        216.0  ...
# 2                                        218.0  ...
# 3                                        218.0  ...
# 4                                         74.0  ...
#
#    Total Students, All Grades (Excludes AE) [District] 2020-21  \
# 0                                             3501.0
# 1                                             3501.0
# 2                                             3501.0
# 3                                             3501.0
# 4                                             9409.0
#
#    Full-Time Equivalent (FTE) Teachers [District] 2020-21  \
# 0                                             166.07
# 1                                             166.07
# 2                                             166.07
# 3                                             166.07
# 4                                             502.56
#
#    Pupil/Teacher Ratio [District] 2020-21  _merge  State Postal Code  \
# 0                                   21.08    both                 CA
# 1                                   21.08    both                 CA
# 2                                   21.08    both                 CA
# 3                                   21.08    both                 CA
# 4                                   18.72    both                 CA
#
#    State FIPS Code  District ID  Estimated Total Population  \
# 0                6         1860                       20467
# 1                6         1860                       20467
# 2                6         1860                       20467
# 3                6         1860                       20467
# 4                6         4740                      123764
#
#    Estimated Population 5-17  est_num_u17_pov
# 0                       3218              168
# 1                       3218              168
# 2                       3218              168
# 3                       3218              168
# 4                       9695              653
#
# [5 rows x 54 columns]

# %%
df.sample(4).T
# Out:
#                                                                       18218  \
# Unnamed: 0                                                            18218
# Unnamed: 0.1                                                          19380
# Unnamed: 0.1.1                                                        29907
# County Code                                                              45
# District Code                                                         70128
# School Code                                                         6050546
# Test Year_x                                                            2021
# Student Group ID                                                          1
# Total Tested at Reporting Level                                        67.0
# Total Tested with Scores at Reporting Level                            65.0
# Grade                                                                    13
# Test ID                                                                 NaN
# Students Enrolled                                                      70.0
# Students Tested                                                        67.0
# Mean Scale Score                                                        NaN
# Percentage Standard Exceeded                                           7.69
# Percentage Standard Met                                               21.54
# Percentage Standard Met and Above                                     29.23
# Percentage Standard Nearly Met                                        30.77
# Percentage Standard Not Met                                            40.0
# Students with Scores                                                   65.0
# Area 1 Percentage Above Standard                                      10.77
# Area 1 Percentage Near Standard                                       49.23
# Area 1 Percentage Below Standard                                       40.0
# Area 2 Percentage Above Standard                                       7.69
# Area 2 Percentage Near Standard                                       55.38
# Area 2 Percentage Below Standard                                      36.92
# Area 3 Percentage Above Standard                                       6.15
# Area 3 Percentage Near Standard                                       66.15
# Area 3 Percentage Below Standard                                      27.69
# Area 4 Percentage Above Standard                                        0.0
# Area 4 Percentage Near Standard                                         0.0
# Area 4 Percentage Below Standard                                        0.0
# Type ID_x                                                                 7
# Test Year_y                                                            2021
# Type ID_y                                                                 7
# County Name                                                          Shasta
# District Name                                       shasta union elementary
# School Name                                               Shasta Elementary
# Zip Code                                                            96087.0
# State Name [District] Latest available year                      California
# State Name [District] 2020-21                                    CALIFORNIA
# Agency ID - NCES Assigned [District] Latest ava...                 636570.0
# County Name [District] 2020-21                                Shasta County
# Total Students, All Grades (Excludes AE) [Distr...                    114.0
# Full-Time Equivalent (FTE) Teachers [District] ...                      6.4
# Pupil/Teacher Ratio [District] 2020-21                                17.81
# _merge                                                                 both
# State Postal Code                                                        CA
# State FIPS Code                                                           6
# District ID                                                           36570
# Estimated Total Population                                             2316
# Estimated Population 5-17                                               222
# est_num_u17_pov                                                          32
#
#                                                                       4047   \
# Unnamed: 0                                                             4047
# Unnamed: 0.1                                                           4571
# Unnamed: 0.1.1                                                         7736
# County Code                                                              16
# District Code                                                         63917
# School Code                                                         6010409
# Test Year_x                                                            2021
# Student Group ID                                                          1
# Total Tested at Reporting Level                                       222.0
# Total Tested with Scores at Reporting Level                           220.0
# Grade                                                                     4
# Test ID                                                                 NaN
# Students Enrolled                                                      80.0
# Students Tested                                                        31.0
# Mean Scale Score                                                     2416.5
# Percentage Standard Exceeded                                           6.67
# Percentage Standard Met                                               16.67
# Percentage Standard Met and Above                                     23.33
# Percentage Standard Nearly Met                                        33.33
# Percentage Standard Not Met                                           43.33
# Students with Scores                                                   30.0
# Area 1 Percentage Above Standard                                       6.67
# Area 1 Percentage Near Standard                                       73.33
# Area 1 Percentage Below Standard                                       20.0
# Area 2 Percentage Above Standard                                       10.0
# Area 2 Percentage Near Standard                                        50.0
# Area 2 Percentage Below Standard                                       40.0
# Area 3 Percentage Above Standard                                       3.33
# Area 3 Percentage Near Standard                                       76.67
# Area 3 Percentage Below Standard                                       20.0
# Area 4 Percentage Above Standard                                      13.33
# Area 4 Percentage Near Standard                                        60.0
# Area 4 Percentage Below Standard                                      26.67
# Type ID_x                                                                 7
# Test Year_y                                                            2021
# Type ID_y                                                                 7
# County Name                                                           Kings
# District Name                                            hanford elementary
# School Name                                         Lee Richmond Elementary
# Zip Code                                                            93230.0
# State Name [District] Latest available year                      California
# State Name [District] 2020-21                                    CALIFORNIA
# Agency ID - NCES Assigned [District] Latest ava...                 616470.0
# County Name [District] 2020-21                                 Kings County
# Total Students, All Grades (Excludes AE) [Distr...                   5690.0
# Full-Time Equivalent (FTE) Teachers [District] ...                   240.03
# Pupil/Teacher Ratio [District] 2020-21                                23.71
# _merge                                                                 both
# State Postal Code                                                        CA
# State FIPS Code                                                           6
# District ID                                                           16470
# Estimated Total Population                                            44391
# Estimated Population 5-17                                              6660
# est_num_u17_pov                                                        1161
#
#                                                                  4545   \
# Unnamed: 0                                                        4545
# Unnamed: 0.1                                                      5045
# Unnamed: 0.1.1                                                    8452
# County Code                                                         17
# District Code                                                    64055
# School Code                                                    1736008
# Test Year_x                                                       2021
# Student Group ID                                                     1
# Total Tested at Reporting Level                                   88.0
# Total Tested with Scores at Reporting Level                       88.0
# Grade                                                               11
# Test ID                                                            NaN
# Students Enrolled                                                111.0
# Students Tested                                                   88.0
# Mean Scale Score                                                2538.9
# Percentage Standard Exceeded                                      9.09
# Percentage Standard Met                                          29.55
# Percentage Standard Met and Above                                38.64
# Percentage Standard Nearly Met                                   29.55
# Percentage Standard Not Met                                      31.82
# Students with Scores                                              88.0
# Area 1 Percentage Above Standard                                 18.18
# Area 1 Percentage Near Standard                                  52.27
# Area 1 Percentage Below Standard                                 29.55
# Area 2 Percentage Above Standard                                  6.82
# Area 2 Percentage Near Standard                                  55.68
# Area 2 Percentage Below Standard                                  37.5
# Area 3 Percentage Above Standard                                  3.41
# Area 3 Percentage Near Standard                                  80.68
# Area 3 Percentage Below Standard                                 15.91
# Area 4 Percentage Above Standard                                 11.36
# Area 4 Percentage Near Standard                                  69.32
# Area 4 Percentage Below Standard                                 19.32
# Type ID_x                                                            7
# Test Year_y                                                       2021
# Type ID_y                                                            7
# County Name                                                       Lake
# District Name                                       middletown unified
# School Name                                            Middletown High
# Zip Code                                                       95461.0
# State Name [District] Latest available year                 California
# State Name [District] 2020-21                               CALIFORNIA
# Agency ID - NCES Assigned [District] Latest ava...            624750.0
# County Name [District] 2020-21                             Lake County
# Total Students, All Grades (Excludes AE) [Distr...              1391.0
# Full-Time Equivalent (FTE) Teachers [District] ...                67.6
# Pupil/Teacher Ratio [District] 2020-21                           20.58
# _merge                                                            both
# State Postal Code                                                   CA
# State FIPS Code                                                      6
# District ID                                                      24750
# Estimated Total Population                                       10023
# Estimated Population 5-17                                         1778
# est_num_u17_pov                                                    213
#
#                                                                            10036
# Unnamed: 0                                                                 10036
# Unnamed: 0.1                                                               11220
# Unnamed: 0.1.1                                                             17778
# County Code                                                                   31
# District Code                                                              66787
# School Code                                                               126664
# Test Year_x                                                                 2021
# Student Group ID                                                               1
# Total Tested at Reporting Level                                             83.0
# Total Tested with Scores at Reporting Level                                 83.0
# Grade                                                                          7
# Test ID                                                                      NaN
# Students Enrolled                                                            NaN
# Students Tested                                                              NaN
# Mean Scale Score                                                             NaN
# Percentage Standard Exceeded                                                 NaN
# Percentage Standard Met                                                      NaN
# Percentage Standard Met and Above                                            NaN
# Percentage Standard Nearly Met                                               NaN
# Percentage Standard Not Met                                                  NaN
# Students with Scores                                                         NaN
# Area 1 Percentage Above Standard                                             NaN
# Area 1 Percentage Near Standard                                              NaN
# Area 1 Percentage Below Standard                                             NaN
# Area 2 Percentage Above Standard                                             NaN
# Area 2 Percentage Near Standard                                              NaN
# Area 2 Percentage Below Standard                                             NaN
# Area 3 Percentage Above Standard                                             NaN
# Area 3 Percentage Near Standard                                              NaN
# Area 3 Percentage Below Standard                                             NaN
# Area 4 Percentage Above Standard                                             NaN
# Area 4 Percentage Near Standard                                              NaN
# Area 4 Percentage Below Standard                                             NaN
# Type ID_x                                                                     10
# Test Year_y                                                                 2021
# Type ID_y                                                                     10
# County Name                                                               Placer
# District Name                                            auburn union elementary
# School Name                                         Alta Vista Community Charter
# Zip Code                                                                 95603.0
# State Name [District] Latest available year                           California
# State Name [District] 2020-21                                         CALIFORNIA
# Agency ID - NCES Assigned [District] Latest ava...                      603480.0
# County Name [District] 2020-21                                     Placer County
# Total Students, All Grades (Excludes AE) [Distr...                        1741.0
# Full-Time Equivalent (FTE) Teachers [District] ...                         82.75
# Pupil/Teacher Ratio [District] 2020-21                                     21.04
# _merge                                                                      both
# State Postal Code                                                             CA
# State FIPS Code                                                                6
# District ID                                                                 3480
# Estimated Total Population                                                 38143
# Estimated Population 5-17                                                   3343
# est_num_u17_pov                                                              332

# %%
df[df['Zip Code']==94116.0].sample(5).T
# Out:
#                                                                      14816  \
# Unnamed: 0                                                           14816
# Unnamed: 0.1                                                         15215
# Unnamed: 0.1.1                                                       23617
# County Code                                                             38
# District Code                                                        68478
# School Code                                                        3833241
# Test Year_x                                                           2021
# Student Group ID                                                         1
# Total Tested at Reporting Level                                        NaN
# Total Tested with Scores at Reporting Level                            NaN
# Grade                                                                   13
# Test ID                                                                NaN
# Students Enrolled                                                    486.0
# Students Tested                                                        NaN
# Mean Scale Score                                                       NaN
# Percentage Standard Exceeded                                           NaN
# Percentage Standard Met                                                NaN
# Percentage Standard Met and Above                                      NaN
# Percentage Standard Nearly Met                                         NaN
# Percentage Standard Not Met                                            NaN
# Students with Scores                                                   NaN
# Area 1 Percentage Above Standard                                       NaN
# Area 1 Percentage Near Standard                                        NaN
# Area 1 Percentage Below Standard                                       NaN
# Area 2 Percentage Above Standard                                       NaN
# Area 2 Percentage Near Standard                                        NaN
# Area 2 Percentage Below Standard                                       NaN
# Area 3 Percentage Above Standard                                       NaN
# Area 3 Percentage Near Standard                                        NaN
# Area 3 Percentage Below Standard                                       NaN
# Area 4 Percentage Above Standard                                       NaN
# Area 4 Percentage Near Standard                                        NaN
# Area 4 Percentage Below Standard                                       NaN
# Type ID_x                                                                7
# Test Year_y                                                           2021
# Type ID_y                                                                7
# County Name                                                  San Francisco
# District Name                                        san francisco unified
# School Name                                         Lincoln (Abraham) High
# Zip Code                                                           94116.0
# State Name [District] Latest available year                     California
# State Name [District] 2020-21                                   CALIFORNIA
# Agency ID - NCES Assigned [District] Latest ava...                634410.0
# County Name [District] 2020-21                        San Francisco County
# Total Students, All Grades (Excludes AE) [Distr...                 51790.0
# Full-Time Equivalent (FTE) Teachers [District] ...                 2501.58
# Pupil/Teacher Ratio [District] 2020-21                                20.7
# _merge                                                                both
# State Postal Code                                                       CA
# State FIPS Code                                                          6
# District ID                                                          34410
# Estimated Total Population                                          866606
# Estimated Population 5-17                                            78720
# est_num_u17_pov                                                       7367
#
#                                                                       14887  \
# Unnamed: 0                                                            14887
# Unnamed: 0.1                                                          15286
# Unnamed: 0.1.1                                                        23688
# County Code                                                              38
# District Code                                                         68478
# School Code                                                         6059851
# Test Year_x                                                            2021
# Student Group ID                                                          1
# Total Tested at Reporting Level                                         NaN
# Total Tested with Scores at Reporting Level                             NaN
# Grade                                                                     6
# Test ID                                                                 NaN
# Students Enrolled                                                     314.0
# Students Tested                                                         NaN
# Mean Scale Score                                                        NaN
# Percentage Standard Exceeded                                            NaN
# Percentage Standard Met                                                 NaN
# Percentage Standard Met and Above                                       NaN
# Percentage Standard Nearly Met                                          NaN
# Percentage Standard Not Met                                             NaN
# Students with Scores                                                    NaN
# Area 1 Percentage Above Standard                                        NaN
# Area 1 Percentage Near Standard                                         NaN
# Area 1 Percentage Below Standard                                        NaN
# Area 2 Percentage Above Standard                                        NaN
# Area 2 Percentage Near Standard                                         NaN
# Area 2 Percentage Below Standard                                        NaN
# Area 3 Percentage Above Standard                                        NaN
# Area 3 Percentage Near Standard                                         NaN
# Area 3 Percentage Below Standard                                        NaN
# Area 4 Percentage Above Standard                                        NaN
# Area 4 Percentage Near Standard                                         NaN
# Area 4 Percentage Below Standard                                        NaN
# Type ID_x                                                                 7
# Test Year_y                                                            2021
# Type ID_y                                                                 7
# County Name                                                   San Francisco
# District Name                                         san francisco unified
# School Name                                         Hoover (Herbert) Middle
# Zip Code                                                            94116.0
# State Name [District] Latest available year                      California
# State Name [District] 2020-21                                    CALIFORNIA
# Agency ID - NCES Assigned [District] Latest ava...                 634410.0
# County Name [District] 2020-21                         San Francisco County
# Total Students, All Grades (Excludes AE) [Distr...                  51790.0
# Full-Time Equivalent (FTE) Teachers [District] ...                  2501.58
# Pupil/Teacher Ratio [District] 2020-21                                 20.7
# _merge                                                                 both
# State Postal Code                                                        CA
# State FIPS Code                                                           6
# District ID                                                           34410
# Estimated Total Population                                           866606
# Estimated Population 5-17                                             78720
# est_num_u17_pov                                                        7367
#
#                                                                       14891  \
# Unnamed: 0                                                            14891
# Unnamed: 0.1                                                          15290
# Unnamed: 0.1.1                                                        23692
# County Code                                                              38
# District Code                                                         68478
# School Code                                                         6059851
# Test Year_x                                                            2021
# Student Group ID                                                          1
# Total Tested at Reporting Level                                         NaN
# Total Tested with Scores at Reporting Level                             NaN
# Grade                                                                     8
# Test ID                                                                 NaN
# Students Enrolled                                                     316.0
# Students Tested                                                         NaN
# Mean Scale Score                                                        NaN
# Percentage Standard Exceeded                                            NaN
# Percentage Standard Met                                                 NaN
# Percentage Standard Met and Above                                       NaN
# Percentage Standard Nearly Met                                          NaN
# Percentage Standard Not Met                                             NaN
# Students with Scores                                                    NaN
# Area 1 Percentage Above Standard                                        NaN
# Area 1 Percentage Near Standard                                         NaN
# Area 1 Percentage Below Standard                                        NaN
# Area 2 Percentage Above Standard                                        NaN
# Area 2 Percentage Near Standard                                         NaN
# Area 2 Percentage Below Standard                                        NaN
# Area 3 Percentage Above Standard                                        NaN
# Area 3 Percentage Near Standard                                         NaN
# Area 3 Percentage Below Standard                                        NaN
# Area 4 Percentage Above Standard                                        NaN
# Area 4 Percentage Near Standard                                         NaN
# Area 4 Percentage Below Standard                                        NaN
# Type ID_x                                                                 7
# Test Year_y                                                            2021
# Type ID_y                                                                 7
# County Name                                                   San Francisco
# District Name                                         san francisco unified
# School Name                                         Hoover (Herbert) Middle
# Zip Code                                                            94116.0
# State Name [District] Latest available year                      California
# State Name [District] 2020-21                                    CALIFORNIA
# Agency ID - NCES Assigned [District] Latest ava...                 634410.0
# County Name [District] 2020-21                         San Francisco County
# Total Students, All Grades (Excludes AE) [Distr...                  51790.0
# Full-Time Equivalent (FTE) Teachers [District] ...                  2501.58
# Pupil/Teacher Ratio [District] 2020-21                                 20.7
# _merge                                                                 both
# State Postal Code                                                        CA
# State FIPS Code                                                           6
# District ID                                                           34410
# Estimated Total Population                                           866606
# Estimated Population 5-17                                             78720
# est_num_u17_pov                                                        7367
#
#                                                                      14817  \
# Unnamed: 0                                                           14817
# Unnamed: 0.1                                                         15216
# Unnamed: 0.1.1                                                       23618
# County Code                                                             38
# District Code                                                        68478
# School Code                                                        3833241
# Test Year_x                                                           2021
# Student Group ID                                                         1
# Total Tested at Reporting Level                                        NaN
# Total Tested with Scores at Reporting Level                            NaN
# Grade                                                                   11
# Test ID                                                                NaN
# Students Enrolled                                                    486.0
# Students Tested                                                        NaN
# Mean Scale Score                                                       NaN
# Percentage Standard Exceeded                                           NaN
# Percentage Standard Met                                                NaN
# Percentage Standard Met and Above                                      NaN
# Percentage Standard Nearly Met                                         NaN
# Percentage Standard Not Met                                            NaN
# Students with Scores                                                   NaN
# Area 1 Percentage Above Standard                                       NaN
# Area 1 Percentage Near Standard                                        NaN
# Area 1 Percentage Below Standard                                       NaN
# Area 2 Percentage Above Standard                                       NaN
# Area 2 Percentage Near Standard                                        NaN
# Area 2 Percentage Below Standard                                       NaN
# Area 3 Percentage Above Standard                                       NaN
# Area 3 Percentage Near Standard                                        NaN
# Area 3 Percentage Below Standard                                       NaN
# Area 4 Percentage Above Standard                                       NaN
# Area 4 Percentage Near Standard                                        NaN
# Area 4 Percentage Below Standard                                       NaN
# Type ID_x                                                                7
# Test Year_y                                                           2021
# Type ID_y                                                                7
# County Name                                                  San Francisco
# District Name                                        san francisco unified
# School Name                                         Lincoln (Abraham) High
# Zip Code                                                           94116.0
# State Name [District] Latest available year                     California
# State Name [District] 2020-21                                   CALIFORNIA
# Agency ID - NCES Assigned [District] Latest ava...                634410.0
# County Name [District] 2020-21                        San Francisco County
# Total Students, All Grades (Excludes AE) [Distr...                 51790.0
# Full-Time Equivalent (FTE) Teachers [District] ...                 2501.58
# Pupil/Teacher Ratio [District] 2020-21                                20.7
# _merge                                                                both
# State Postal Code                                                       CA
# State FIPS Code                                                          6
# District ID                                                          34410
# Estimated Total Population                                          866606
# Estimated Population 5-17                                            78720
# est_num_u17_pov                                                       7367
#
#                                                                       14890
# Unnamed: 0                                                            14890
# Unnamed: 0.1                                                          15289
# Unnamed: 0.1.1                                                        23691
# County Code                                                              38
# District Code                                                         68478
# School Code                                                         6059851
# Test Year_x                                                            2021
# Student Group ID                                                          1
# Total Tested at Reporting Level                                         NaN
# Total Tested with Scores at Reporting Level                             NaN
# Grade                                                                     6
# Test ID                                                                 NaN
# Students Enrolled                                                     314.0
# Students Tested                                                         NaN
# Mean Scale Score                                                        NaN
# Percentage Standard Exceeded                                            NaN
# Percentage Standard Met                                                 NaN
# Percentage Standard Met and Above                                       NaN
# Percentage Standard Nearly Met                                          NaN
# Percentage Standard Not Met                                             NaN
# Students with Scores                                                    NaN
# Area 1 Percentage Above Standard                                        NaN
# Area 1 Percentage Near Standard                                         NaN
# Area 1 Percentage Below Standard                                        NaN
# Area 2 Percentage Above Standard                                        NaN
# Area 2 Percentage Near Standard                                         NaN
# Area 2 Percentage Below Standard                                        NaN
# Area 3 Percentage Above Standard                                        NaN
# Area 3 Percentage Near Standard                                         NaN
# Area 3 Percentage Below Standard                                        NaN
# Area 4 Percentage Above Standard                                        NaN
# Area 4 Percentage Near Standard                                         NaN
# Area 4 Percentage Below Standard                                        NaN
# Type ID_x                                                                 7
# Test Year_y                                                            2021
# Type ID_y                                                                 7
# County Name                                                   San Francisco
# District Name                                         san francisco unified
# School Name                                         Hoover (Herbert) Middle
# Zip Code                                                            94116.0
# State Name [District] Latest available year                      California
# State Name [District] 2020-21                                    CALIFORNIA
# Agency ID - NCES Assigned [District] Latest ava...                 634410.0
# County Name [District] 2020-21                         San Francisco County
# Total Students, All Grades (Excludes AE) [Distr...                  51790.0
# Full-Time Equivalent (FTE) Teachers [District] ...                  2501.58
# Pupil/Teacher Ratio [District] 2020-21                                 20.7
# _merge                                                                 both
# State Postal Code                                                        CA
# State FIPS Code                                                           6
# District ID                                                           34410
# Estimated Total Population                                           866606
# Estimated Population 5-17                                             78720
# est_num_u17_pov                                                        7367
