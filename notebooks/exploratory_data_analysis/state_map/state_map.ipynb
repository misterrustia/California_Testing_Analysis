# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
ca_map = gpd.read_file('CA_Counties')

# %%
fig,ax = plt.subplots(figsize=(12,12))
ca_map.plot(ax=ax)
plt.show()
